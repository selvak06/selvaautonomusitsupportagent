# %%
import os
from openai import OpenAI
from google.colab import userdata

# %%
def query_openai(prompt):
    print(f"\n--- Querying OpenAI (GPT-4.1 Mini) ---")

    client = OpenAI(api_key=userdata.get('OPENAI_APIKEY'))

    try:
        response = client.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.7
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"OpenAI Error: {e}"

# %%
test_prompt = "What is the point of using nosql databases in engineering systems in under 3 sentences"

# %%
print(query_openai(test_prompt))
# Out:
# --- Querying OpenAI (GPT-4.1 Mini) ---
# NoSQL databases are used in engineering systems to handle large volumes of unstructured or semi-structured data with high scalability and flexibility. They are particularly useful for applications requiring rapid data ingestion and retrieval, such as real-time analytics and high-traffic web applications, as they can distribute data across multiple servers easily. Additionally, NoSQL databases often provide schema-less data models, which allow for more agile development and iteration.

# %%
def query_openrouter(prompt, model_name="meta-llama/llama-3.1-70b-instruct"):
    print(f"\n--- Querying OpenRouter ({model_name}) ---")

    client = OpenAI(
        base_url="https://openrouter.ai/api/v1",
        api_key=userdata.get('OPENROUTER_APIKEY'),
    )

    try:
        response = client.chat.completions.create(
            model=model_name,
            messages=[
                {"role": "user", "content": prompt}
            ]
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"OpenRouter Error: {e}"

# %%
print(query_openrouter(test_prompt, model_name="x-ai/grok-4-fast"))
# Out:
# --- Querying OpenRouter (x-ai/grok-4-fast) ---
# NoSQL databases are particularly valuable in engineering systems for their ability to handle massive volumes of unstructured or semi-structured data, such as sensor data from IoT devices or real-time logs, which traditional relational databases struggle with due to rigid schemas and vertical scaling limitations. They enable horizontal scaling across distributed clusters, improving performance, availability, and fault tolerance in high-traffic or big data environments like web applications and machine learning pipelines. Overall, NoSQL offers flexibility and cost-efficiency for rapidly evolving systems where schema changes are frequent and data velocity is high.

# %%
print(query_openrouter(test_prompt, model_name="deepseek/deepseek-r1"))
# Out:
# --- Querying OpenRouter (deepseek/deepseek-r1) ---
# NoSQL databases excel in scalability and flexible data models, making them ideal for handling large volumes of diverse or rapidly changing data in modern applications. They offer high performance and distributed architectures suited for real-time and big data engineering systems. This agility allows engineering teams to iterate quickly without stringent schema constraints.
